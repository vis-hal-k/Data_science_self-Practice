# %% [markdown]
# # Numphy

# %% [markdown]
# Numpy is a Pyhton Package which stands For __*Numerical Python*__.
# This was Created in 2005 by __Travis Oliphant__
# ##### Using Numpy we can perform the following functionalities :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Numpy is often called as an alternate for __Matlab__.

# %% [markdown]
# Numpy is used with package like __SciPy(Scientific Python)__ and __Mat-Plotlib (Plotting Library)__ and this makes it capable to replace **MATLAB**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
# No error means Numpy correctly install

# %% [markdown]
# <h2 style = "color: Purple; text-align: center;" > Numpy vs List  </h2>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%timeit
a=[]
for i in range(1,15):
    a.append(i*10)
# Out:
# 3.49 µs ± 241 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# this is for LIST
# %timeit [i**2 for i in range(1,11)]
# Out:
# 6.12 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# same Work in NUMPY 
import numpy as np
# %timeit np.arange(1,11)**2
# Out:
# 3.71 µs ± 714 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
