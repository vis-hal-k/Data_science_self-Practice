# %% [markdown]
# # Contents

# %% [markdown]
# 1. Data Types
# 2. Conversion between Data types
# 3. List its and Operations
# 4. Tuple its and Operations
# 5. Dictionary its and Operations
# 6. Set its and Operations
# 7. String its and Operations

# %% [markdown]
# ### 1. Data Types in Python

# %% [markdown]
# Every value in Python has a datatype. Since everything is an object in Python programming, data types are actually classes and variables are instance (object) of these classes.
#
# Basically, we have 4 data types - Numeric, Boolean, String and Sequence

# %% [markdown]
# Numbers
#
# Integers, floating point numbers and complex numbers falls under Python numbers category. They are defined as int, float and complex class in Python.
#
# We can use the type() function to know which class a variable or a value belongs to and the isinstance() function to check if an object belongs to a particular class.

# %%
a = 5                               #data type is implicitly set to integer
print(a, " is of type", type(a))
# Out:
# 5  is of type <class 'int'>

# %%
isinstance(5, int)
# Out:
# True

# %%
a = 2.5                            #data type is changed to float
print(a, " is of type", type(a))
# Out:
# 2.5  is of type <class 'float'>

# %%
a = 1 + 2j                          #data type is changed to complex number
print(a, " is complex number?") 
print(isinstance(1+2j, complex))

# format is a+bj
# Out:
# (1+2j)  is complex number?
# True

# %% [markdown]
# Boolean
#
# Boolean represents the truth values False and True

# %%
a = True                          #a is a boolean type
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
# Strings
#
# String is sequence of Unicode characters.
#
# We can use single quotes or double quotes to represent strings.
#
# Multi-line strings can be denoted using triple quotes, ''' or """.
#
# A string in Python consists of a series or sequence of characters - letters, numbers, and special characters.
#
# Strings can be indexed - often synonymously called subscripted as well.
#
# Similar to C, the first character of a string has the index 0.

# %%
s = "abc123@!"

# %%
s = "This is Online AI course"
print(s)
# Out:
# This is Online AI course

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
isinstance(s, str)
# Out:
# True

# %%
# Indexing
print(s[8])
#last char s[len(s)-1] or s[-1]
# Out:
# O

# %%
s[9]
# Out:
# 'n'

# %%
ss = "ssts"

# %%
ss[1]
# Out:
# 's'

# %%
#slicing
s[5:9] #Syntax - initial index:final index
# final index is exclusive
# Out:
# 'is O'

# %%
s[2:7]
# Out:
# 'is is'

# %%
s[2:10]
# Out:
# 'is is On'

# %% [markdown]
# Sequence data types - List, Tuple, Dictionary, Set

# %% [markdown]
# List
#
# List is an ordered sequence of heterogenous items. It is one of the most used datatype in Python and is very flexible. All the items in a list do not need to be of the same type.
#
# Declaring a list is , Items separated by commas are enclosed within brackets [ ].
#
# They can be indexed, sliced and re-assigned.

# %%
a = [10, 20.5, "Hello"]
print(a)
print(a[1])               #print 1st index element
# Out:
# [10, 20.5, 'Hello']
# 20.5

# %%
# Creating an Empty list
a = list()

# %%
a = []

# %%
a
# Out:
# []

# %%
# Creating a list from a string
a = list("Python is great!")

# %%
print(a)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n', ' ', 'i', 's', ' ', 'g', 'r', 'e', 'a', 't', '!']

# %%
a = list(129735)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 a = list(129735)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# Lists are mutable, meaning, value of elements of a list can be altered.

# %%
a[1] = 30.7
print(a)
# Out:
# [10, 30.7, 'Hello']

# %% [markdown]
# Tuple
#
# Tuple is an ordered sequence of items same as list.The only difference is that tuples are immutable. Tuples once created cannot be modified.
# They can be indexed and sliced but can not be re-assigned

# %%
t = (1, 1.5, "ML")

# %%
t = (2, 5, 7, 7, 7, 7, 7)

# %%
print(t) #extract particular element
# Out:
# (2, 5, 7, 7, 7, 7, 7)

# %%
t[1] = 1.25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 t[1] = 1.25
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Set
#
# Set is an unordered collection of unique items. Set is defined by values separated by comma inside braces { }. Items in a set are not ordered. It means the items can not be indexed.

# %%
a = {10, 30, 20, 40, 5}
print(a)
# Out:
# {20, 5, 40, 10, 30}

# %%
print(type(a))             #print type of a
# Out:
# <class 'set'>

# %%
s = {10, 20, 20, 30, 30, 30}
print(s)                    #automatically set won't consider duplicate elements
# Out:
# {10, 20, 30}

# %%
print(s[1]) #we can't print particular element in set because 
            #it's unorder collections of items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 print(s[1])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Dictionary
#
# Dictionary is an unordered collection of key-value pairs.
#
# In Python, dictionaries are defined within braces {} with each item being a pair in the form key:value. Key and value can be of any type but keys should be immutable.
#
# We can index dictionary based on keys

# %%
d = {'a': "apple", 'b': "bat"}
print(d)
print(d['a'])
# Out:
# {'a': 'apple', 'b': 'bat'}
# apple

# %% [markdown]
# The keys of a dictionary are immutable but values are mutable

# %%
# I can update values corresponding to a key in Dict

# %%
d['a'] = [1,2,3]

# %%
print(d)
# Out:
# {'a': [1, 2, 3], 'b': 'bat'}

# %%
# I can add a new key value pair

d['t'] = 'hello'

# %%
print(d)
# Out:
# {'a': [1, 2, 3], 'b': 'bat', 't': 'hello'}

# %%
# But I can not add a key which itself is of mutable data type like list
# Tuple can be used as a key as it is immutable
# List can't be used
d[(1,7,9)] = "numbers"

# %%
print(d)
# Out:
# {'a': [1, 2, 3], 'b': 'bat', 't': 'hello', (1, 7, 9): 'numbers'}

# %%
d[[list("world")]] = "list key"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 d[[list("world")]] = "list key"
#
# TypeError: unhashable type: 'list'

# %%
s = {}
print(type(s))
# Out:
# <class 'dict'>

# %% [markdown]
# ### 2. Conversion Between Data Types

# %% [markdown]
# We can convert between different data types by using different type conversion functions like int(), float(), str() etc.

# %%
float(5)     #convert interger to float using float() method
# Out:
# 5.0

# %%
int(100.9)   #convert float to integer using int() method
# Out:
# 100

# %%
str(20)      #convert integer to string
# Out:
# '20'

# %%
int("20")
# Out:
# 20

# %% [markdown]
# Conversion to and from string must contain compatible values.

# %%
int('10p')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 int('10p')
#
# ValueError: invalid literal for int() with base 10: '10p'

# %%
user = "satish"
lines = 100

print("Congratulations, " + user + "! You just wrote " + str(lines) + " lines of code" )
#remove str and gives error
# Out:
# Congratulations, satish! You just wrote 100 lines of code

# %% [markdown]
# We can convert one sequence to other

# %%
a = [1, 2, 3]

print(type(a))      #type of a is list 

s = set(a)          #convert list to set using set() method

print(type(s))      #now type of s is set
# Out:
# <class 'list'>
# <class 'set'>

# %%
list("Hello")       #convert String to list using list() method
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %% [markdown]
# ### 3. List and its Operations

# %% [markdown]
# 1. Append
# 2. Extend
# 3. Insert
# 4. Remove
# 5. pop
# 6. index
# 7. reverse
# 8. len
# 9. sort
# 10. min and max
# 11. count
# 12. clear
# 13. Concatenation
# 14. Multiply
# 15. Indexing and Slicing

# %% [markdown]
# The append() method is used to add elements at the end of the list. This method can only add a single element at a time.

# %%
myList = [1,2,3]

# %%
myList.append(4)

# %%
print(myList)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# The extend() method is used to add more than one element at the end of the list. Although it can add more than one element, unlike append(), it adds them at the end of the list like append().

# %% [markdown]
# Understanding input and output is very crucial

# %%
myList.extend((4, 5, 6)) # It takes a list as an input

# %%
print(myList)
# Out:
# [1, 2, 3, 4, 4, 5, 6]

# %% [markdown]
# The insert() method can add an element at a given position in the list. Thus, unlike append(), it can add elements at any position, but like append(), it can add only one element at a time. This method takes two arguments. The first argument specifies the position, and the second argument specifies the element to be inserted.

# %%
myList.insert(5, "string")
print(myList)
# Out:
# [1, 2, 3, 4, 4, 'string', 5, 6]

# %%
myList.append(4)

# %%
print(myList)
# Out:
# [1, 2, 3, 4, 4, 'string', 5, 6, 4]

# %% [markdown]
# The remove() method is used to remove an element from the list. In the case of multiple occurrences of the same element, only the first occurrence is removed.

# %%
myList.remove(4)

# %%
myList
# Out:
# [1, 2, 3, 4, 'string', 5, 6, 4]

# %%
myList.remove('makes learning fun!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 myList.remove('makes learning fun!')
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# The method pop() can remove an element from any position in the list. The parameter supplied to this method is the index of the element to be removed.
#
# It by default removes the last element. It also returns the element removed from the list.

# %%
 a = myList.pop()

# %%
myList
# Out:
# [1, 2, 3, 4, 'string', 5, 6]

# %%
a
# Out:
# 4

# %%
 a = myList.pop(2)

# %%
myList
# Out:
# [1, 2, 4, 'string', 5, 6]

# %%
a
# Out:
# 3

# %% [markdown]
# The index() method returns the position of the first occurrence of the given element. It takes two optional parameters – the beginning index and the end index. These parameters define the start and end position of the search area on the list. When supplied, the element is searched only in the sub-list bound by the begin and end indices. When not supplied, the element is searched in the whole list.

# %%
myList.append(4)

# %%
print(myList)
# Out:
# [1, 2, 4, 'string', 5, 6, 4]

# %%
print(myList.index(4))  # arg is element and not index. Output is index
# Out:
# 2

# %%
myList[3:7]
# Out:
# ['string', 5, 6, 4]

# %%
print(myList.index(4, 3, 7)) # The end index is exclusive
# Out:
# 6

# %%
print(myList.index(4, 4, 7))
# Out:
# 6

# %% [markdown]
# The reverse() operation is used to reverse the elements of the list. This method modifies the original list. To reverse a list without modifying the original one, we use the slice operation with negative indices. Specifying negative indices iterates the list from the rear end to the front end of the list.

# %%
myList.reverse()     # modifies the original list
print(myList)
# Out:
# [1, 2, 4, 'string', 5, 6, 4]

# %%
myList[::-1]
# Out:
# [4, 6, 5, 'string', 4, 2, 1]

# %%
revList = myList[::-1] # Something like slicing only

print(revList)
print(myList)
# Out:
# [4, 6, 5, 'string', 4, 2, 1]
# [1, 2, 4, 'string', 5, 6, 4]

# %% [markdown]
# The len() method returns the length of the list, i.e. the number of elements in the list.

# %%
len(myList)
# Out:
# 7

# %% [markdown]
# The sort method sorts the list in ascending order. This operation can only be performed on homogeneous lists, i.e. lists having elements of similar type. It also changes the original list.

# %%
yourList = [4, 2, 6, 5, 0, 1]
yourList.sort()
print(yourList)
# Out:
# [0, 1, 2, 4, 5, 6]

# %%
yourList.sort(reverse = True)

# %%
yourList
# Out:
# [6, 5, 4, 2, 1, 0]

# %%
# A new list with strings
newList = ['c','e', 'a', 'p', 'z', 'b', 'a']
newList.sort()
print(newList)
# Out:
# ['a', 'a', 'b', 'c', 'e', 'p', 'z']

# %% [markdown]
# The min() method returns the minimum value in the list. The max() method returns the maximum value in the list. Both the methods accept only homogeneous lists, i.e. lists having elements of similar type.

# %%
print(min(yourList))
print(max(yourList))
# Out:
# 0
# 6

# %%
print(min(newList))
# Out:
# a

# %% [markdown]
# The function count() returns the number of occurrences of a given element in the list.

# %%
myList
# Out:
# [1, 2, 4, 'string', 5, 6, 4]

# %%
print(myList.count(4)) #Takes element as input
# Out:
# 2

# %% [markdown]
# This function erases all the elements from the list and empties them.

# %%
myList.clear()

# %%
myList
# Out:
# []

# %%
myList = [1, 2, 3, 4, 'string', 5, 4]

# %% [markdown]
# The concatenate operation is used to merge two lists and return a single list. The + sign is used to perform the concatenation. Note that the individual lists are not modified, and a new combined list is returned.

# %%
yourList = [85, 9, 'Python', 'is fun!']
print(myList+yourList)
# Out:
# [1, 2, 3, 4, 'string', 5, 4, 85, 9, 'Python', 'is fun!']

# %%
# Adding a list and a string
newList = myList + "abc"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [131], in <cell line: 2>()
#       1 # Adding a list and a string
# ----> 2 newList = myList + "abc"
#
# TypeError: can only concatenate list (not "str") to list

# %% [markdown]
# Python also allows multiplying the list n times. The resultant list is the original list iterated n times.

# %%
print(myList*2)
# Out:
# [1, 2, 3, 4, 'string', 5, 4, 1, 2, 3, 4, 'string', 5, 4]

# %%
print(myList) # Did not change the original list
# Out:
# [1, 2, 3, 4, 'string', 5, 4]

# %% [markdown]
# Indexing is used to select an element at a particular index. The slice operation is used to print a section of the list. The slice operation returns a specific range of elements. It does not modify the original list.

# %%
myList[3] #input is the index. Indexes start with zero
# Out:
# 4

# %%
myList[1:5] #The end index is exclusive
# Out:
# [2, 3, 4, 'string']

# %%
myList[-1]
# Out:
# 4

# %%
myList[-3]
# Out:
# 'string'

# %%
myList[1:-1] #The end index is exclusive
# Out:
# [2, 3, 4, 'string', 5]

# %%
# Steps in Slicing
myList[1:5:2] #The end index is exclusive
# Out:
# [2, 4]

# %%
myList[-1::-1] # Walk backwards
# Out:
# [4, 5, 'string', 4, 3, 2, 1]

# %%
myList[::-1] #The default start is 0. The default end is the last element and walk backwards
# Out:
# [4, 5, 'string', 4, 3, 2, 1]

# %% [markdown]
# ### 4. Tuple and its operations

# %% [markdown]
# Tuples and lists allow duplicate items.
# The keys in a dict can't be duplicate
# Sets - ?

# %% [markdown]
# Indexing and Slicing similar to list - HW
#
# len - HW
#
# Concatenation - HW
#
# index - HW
#
# count - Returns the frequency of occurrence of a specified value - HW
#
# max and min - HW
#
# del tuple_name
#
# all - Returns true if all element are true or if tuple is empty
#
# any - return true if any element of the tuple is true. if tuple is empty, return false
#
# sum
#
# sorted - input elements in the tuple and return a new sorted list

# %%
myTup = (10,4,33,45,3,67)

# %%
del myTup

# %%
print(myTup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [143], in <cell line: 1>()
# ----> 1 print(myTup)
#
# NameError: name 'myTup' is not defined

# %%
myTup = (10,4,33,45,3,67)

# %%
print(any((True, True, False)))
# Out:
# True

# %%
print(any(tuple()))
# Out:
# False

# %% [markdown]
# Do the same with any - HW

# %%
sum(myTup)
# Out:
# 162

# %%
newTup = sorted(myTup)

# %%
print(newTup)
print(myTup)
# Out:
# [3, 4, 10, 33, 45, 67]
# (10, 4, 33, 45, 3, 67)

# %% [markdown]
# BONUS - enumerate - Returns enumerate object of tuple

# %% [markdown]
# enumerate(iterable, start=0)
#
# iterables are something we can iterate over

# %%
l1 = ["eat", "sleep", "repeat"]

# creating enumerate objects
obj1 = enumerate(l1)

print ("Return type:", type(obj1))
print(list(obj1))

# output - list of tuples
# In every tuple - the first element is index and 2nd element is the item of list
# Out:
# Return type: <class 'enumerate'>
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %% [markdown]
# ### 5. Dictionary Operations

# %% [markdown]
# items
#
# keys
#
# values
#
# pop
#
# popitem
#
# get
#
# update
#
# copy
#
# clear

# %%
myDict = {}

# %%
myDict = dict()

# %%
myDict = {1: "a", 2:"b", 3:"c", 4:"d"}

# %%
myDict.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
type(myDict.keys())
# Out:
# dict_keys

# %%
list(myDict.keys())
# Out:
# [1, 2, 3, 4]

# %%
myDict.values()
# Out:
# dict_values(['a', 'b', 'c', 'd'])

# %%
myDict.items()
# Out:
# dict_items([(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')])

# %%
myDict.pop(1) #arg is key name. It returns the value
# Out:
# 'a'

# %%
myDict
# Out:
# {2: 'b', 3: 'c', 4: 'd'}

# %% [markdown]
# Python dictionary popitem() method removes the last inserted key-value pair from the dictionary and returns it as a tuple.

# %%
myDict.popitem()
# Out:
# (4, 'd')

# %% [markdown]
# Python Dictionary get() Method return the value for the given key if present in the dictionary. If not, then it will return None (if get() is used with only one argument).
#
# Syntax : Dict.get(key, default=None)

# %%
myDict
# Out:
# {2: 'b', 3: 'c'}

# %%
myDict[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [166], in <cell line: 1>()
# ----> 1 myDict[4]
#
# KeyError: 4

# %%
myDict.get(4)

# %%
myDict.get(3)
# Out:
# 'c'

# %%
myDict.get(1)

# %%
myDict.get(1, "h")
# Out:
# 'h'

# %% [markdown]
# Python Dictionary update() method updates the dictionary with the elements from another dictionary object or from an iterable of key/value pairs.

# %%
myDict
# Out:
# {2: 'b', 3: 'c'}

# %%
myDict[2] = "reass"

# %%
myDict
# Out:
# {2: 'reass', 3: 'c'}

# %%
# Dictionary with three items
Dictionary1 = {'A': 'Hello', 'B': 'World', 'C': 'Star'}
Dictionary2 = {'B': 'Hey', 'C': "moon"}

# Dictionary before Updation
print("Original Dictionary:")
print(Dictionary1)

# update the value of key 'B'
Dictionary1.update(Dictionary2)
print("Dictionary after updation:")
print(Dictionary1)
# Out:
# Original Dictionary:
# {'A': 'Hello', 'B': 'World', 'C': 'Star'}
# Dictionary after updation:
# {'A': 'Hello', 'B': 'Hey', 'C': 'moon'}

# %% [markdown]
# It means that any changes made to a copy of the object do not reflect in the original object. In python, this is implemented using “deepcopy()” function. whereas in shallow copy any changes made to a copy of an object do reflect in the original object.

# %%
newDict = myDict.copy()

# %%
newDict
# Out:
# {2: 'reass', 3: 'c'}

# %%
myDict
# Out:
# {2: 'reass', 3: 'c'}

# %%
newDict[2] = "new"

# %%
newDict
# Out:
# {2: 'new', 3: 'c'}

# %%
myDict
# Out:
# {2: 'reass', 3: 'c'}

# %%
newDict.pop(3)
# Out:
# 'c'

# %%
newDict
# Out:
# {2: 'new'}

# %%
myDict
# Out:
# {2: 'b', 3: 'c'}

# %%
asDict = newDict

# %%
asDict[7] = "as"

# %%
asDict
# Out:
# {2: 'new', 3: 'c', 7: 'as'}

# %%
newDict
# Out:
# {2: 'new', 3: 'c', 7: 'as'}

# %%
newDict.clear()

# %%
newDict
# Out:
# {}

# %%
asDict
# Out:
# {}

# %% [markdown]
# ### 6. Set and its operations

# %% [markdown]
# add - adds a new elements
#
# The set add() method adds a given element to a set if the element is not present in the set. Syntax: set.add(elem) The add() method doesn't add an element to the set if it's already present in it otherwise it will get added to the set.

# %% [markdown]
# A = {0, 2, 4, 6, 8}
# B = {1, 2, 3, 4, 5}
#
# Output :
#  Union : [0, 1, 2, 3, 4, 5, 6, 8]
#
#  Intersection : [2, 4]
#
#  Difference : [8, 0, 6]
#
#  Symmetric difference : [0, 1, 3, 5, 6, 8]

# %% [markdown]
# | for union.
#
# & for intersection.
#
# – for difference
#
# ^ for symmetric difference

# %% [markdown]
# set A = {10, 20, 30, 40, 80}
# set B = {100, 30, 80, 40, 60}
#
# set A - set B = {10, 20}
# set B - set A = {100, 60}
#
# Explanation: A - B is equal to the elements present in A but not in B
#
# B - A is equal to the elements present in B but not in A

# %% [markdown]
# This in-built function of Python Set helps us to get the symmetric difference between two sets, which is equal to the elements present in either of the two sets, but not common to both the sets

# %%
A = {0, 2, 4, 6, 8};
B = {1, 2, 3, 4, 5};

# union
print("Union :", A | B)

# intersection
print("Intersection :", A & B)

# difference
print("Difference :", A - B)

# symmetric difference
print("Symmetric difference :", A ^ B)
# Out:
# Union : {0, 1, 2, 3, 4, 5, 6, 8}
# Intersection : {2, 4}
# Difference : {0, 8, 6}
# Symmetric difference : {0, 1, 3, 5, 6, 8}

# %% [markdown]
# ### 7. String Operations

# %% [markdown]
# Indexing and Slicing - Just like list
#
# lower, upper and Title
#
# count - Returns the number of occurrences of a substring in the string.
#
# endswith - Returns “True” if a string ends with the given suffix. We also have startswith
#
# find - Returns the lowest index of the substring if it is found
#
# index - Returns the position of the first occurrence of a substring in a string
#
# isalnum - 	Checks whether all the characters in a given string is alphanumeric or not
#
# isalpha - Returns “True” if all characters in the string are alphabets
#
# isdigit - Returns “True” if all characters in the string are digits
#
# islower - Checks if all characters in the string are lowercase
#
# lstrip - Returns the string with leading characters removed. We also have rstrip and strip
#
# replace - Replaces all occurrences of a substring with another substring
#
# split

# %%
s = "Hello world!"

# %%
s[3]
# Out:
# 'l'

# %%
s[1:5]
# Out:
# 'ello'

# %%
s.lower()
# Out:
# 'hello world!'

# %%
s
# Out:
# 'Hello world!'

# %%
s.upper()
# Out:
# 'HELLO WORLD!'

# %%
s = "heLLo woRld"

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.count('o')
# Out:
# 2

# %%
s.endswith('o')
# Out:
# False

# %%
s.endswith('d')
# Out:
# True

# %%
s = "hello world 9"

# %%
s.find('llo')
# Out:
# 2

# %%
s.index('ll')
# Out:
# 2

# %%
s.isalpha() # Consider or Include Space
# Out:
# False

# %%
s.isalnum()
# Out:
# False

# %%
ss = "    hello world    "

ss.strip() # by default, the parameter is whitespace
# Out:
# 'hello world'

# %%
s
# Out:
# 'hello world 9'

# %%
s.replace('l', 'L') # syntax - older, newer
# Out:
# 'heLLo worLd 9'

# %%
s = "hello world hi star moon"

# %%
s.split() # Returns a list.By default, it splits on whitespace
# Out:
# ['hello', 'world', 'hi', 'star', 'moon']

# %%
s.split("/")
# Out:
# ['hello world hi star moon']

# %%
s.split("o")
print('hello')
# Out:
# hello
